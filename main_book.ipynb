# %%
# %run calculate_oos.py

# %%
# %run calculate_oos.py

# %%
U, P, Q, OOS = run_simulation.simulate('test.fmu', 1.0, 15, 3, 320)

# %%
U, P, Q, OOS
# Out:
# (np.float64(1.0043065917741425),
#  np.float64(15.000140963080929),
#  np.float64(2.9328122824673755),
#  SimulationResult(True))
